# %%
import os
import pandas as pd

all_files = os.listdir()
sum_files = [file for file in all_files if file.endswith(".sum")]
charge=[['Atom','Charge']] # atom_name + atom_charge
loc=[['Atom','Loc_index']] # atom_name + delocation_index
deloc=[['Atom(A)','Atom(B)','Deloc_index']] # atom_A + atom_B + delocation_index_AB
for output in sum_files:
    file = open(output)
    text = file.readlines()
    for line in range(len(text)):
         if text[line].startswith(('Atom A          q(A)              L(A)')): # ~charge
                i=1
                while True:
                    i+=1
                    if text[line+i].startswith('---'):
                        break
                    data_line = text[line+i].split()
                    charge.append([data_line[0],float(data_line[1])])
         
         if text[line].startswith(('Atom A          N(A)             LI(A)            %Loc(A)')): # ~loc
                i=1
                while True:
                    i+=1
                    if text[line+i].startswith('---'):
                        break
                    data_line = text[line+i].split()
                    loc.append([data_line[0],float(data_line[2])])
        
         if text[line].startswith(('Atom A    Atom B       2*D2(A,B)          DI(A,B)')): # ~deloc
                i=1
                while True:
                    i+=1
                    if text[line+i].startswith(' '):
                        break
                    data_line = text[line+i].split()
                    deloc.append([data_line[0],data_line[1],float(data_line[3])])
    df_charge = pd.DataFrame(charge)
    df_loc = pd.DataFrame(loc)
    df_deloc = pd.DataFrame(deloc)
    df_charge.to_csv(output[:-4]+'_charge.csv', sep=' ', index=False, header=False)
    df_loc.to_csv(output[:-4]+'_loc.csv', sep=' ', index=False, header=False)
    df_deloc.to_csv(output[:-4]+'_deloc.csv', sep=' ', index=False, header=False)
    charge = [charge[0]]
    loc = [loc[0]]
    deloc = [deloc[0]]
    print('Properties extracted from "'+output+'" file')
print('All done !')
# Out:
# Properties extracted from "alanine_00000.sum" file
# Properties extracted from "alanine_01000.sum" file
# Properties extracted from "alanine_02000.sum" file
# Properties extracted from "alanine_03000.sum" file
# Properties extracted from "alanine_04000.sum" file
# Properties extracted from "alanine_05000.sum" file
# Properties extracted from "alanine_06000.sum" file
# Properties extracted from "alanine_07000.sum" file
# Properties extracted from "alanine_08000.sum" file
# Properties extracted from "alanine_09000.sum" file
# Properties extracted from "alanine_10000.sum" file
# Properties extracted from "arginine_00000.sum" file
# Properties extracted from "arginine_01000.sum" file
# Properties extracted from "arginine_02000.sum" file
# Properties extracted from "arginine_03000.sum" file
# Properties extracted from "arginine_04000.sum" file
# Properties extracted from "arginine_05000.sum" file
# Properties extracted from "arginine_06000.sum" file
# Properties extracted from "arginine_07000.sum" file
# Properties extracted from "arginine_08000.sum" file
# Properties extracted from "arginine_09000.sum" file
# Properties extracted from "arginine_10000.sum" file
# Properties extracted from "aspargine_00000.sum" file
# Properties extracted from "aspargine_01000.sum" file
# Properties extracted from "aspargine_02000.sum" file
# Properties extracted from "aspargine_03000.sum" file
# Properties extracted from "aspargine_04000.sum" file
# Properties extracted from "aspargine_05000.sum" file
# Properties extracted from "aspargine_06000.sum" file
# Properties extracted from "aspargine_07000.sum" file
# Properties extracted from "aspargine_08000.sum" file
# Properties extracted from "aspargine_09000.sum" file
# Properties extracted from "aspargine_10000.sum" file
# Properties extracted from "aspartic_00000.sum" file
# Properties extracted from "aspartic_01000.sum" file
# Properties extracted from "aspartic_02000.sum" file
# Properties extracted from "aspartic_03000.sum" file
# Properties extracted from "aspartic_04000.sum" file
# Properties extracted from "aspartic_05000.sum" file
# Properties extracted from "aspartic_06000.sum" file
# Properties extracted from "aspartic_07000.sum" file
# Properties extracted from "aspartic_08000.sum" file
# Properties extracted from "aspartic_09000.sum" file
# Properties extracted from "aspartic_10000.sum" file
# Properties extracted from "cystine_00000.sum" file
# Properties extracted from "cystine_01000.sum" file
# Properties extracted from "cystine_02000.sum" file
# Properties extracted from "cystine_03000.sum" file
# Properties extracted from "cystine_04000.sum" file
# Properties extracted from "cystine_05000.sum" file
# Properties extracted from "cystine_06000.sum" file
# Properties extracted from "cystine_07000.sum" file
# Properties extracted from "cystine_08000.sum" file
# Properties extracted from "cystine_09000.sum" file
# Properties extracted from "cystine_10000.sum" file
# Properties extracted from "glutamate_00000.sum" file
# Properties extracted from "glutamate_01000.sum" file
# Properties extracted from "glutamate_02000.sum" file
# Properties extracted from "glutamate_03000.sum" file
# Properties extracted from "glutamate_04000.sum" file
# Properties extracted from "glutamate_05000.sum" file
# Properties extracted from "glutamate_06000.sum" file
# Properties extracted from "glutamate_07000.sum" file
# Properties extracted from "glutamate_08000.sum" file
# Properties extracted from "glutamate_09000.sum" file
# Properties extracted from "glutamate_10000.sum" file
# Properties extracted from "glutamine_00000.sum" file
# Properties extracted from "glutamine_01000.sum" file
# Properties extracted from "glutamine_02000.sum" file
# Properties extracted from "glutamine_03000.sum" file
# Properties extracted from "glutamine_04000.sum" file
# Properties extracted from "glutamine_05000.sum" file
# Properties extracted from "glutamine_06000.sum" file
# Properties extracted from "glutamine_07000.sum" file
# Properties extracted from "glutamine_08000.sum" file
# Properties extracted from "glutamine_09000.sum" file
# Properties extracted from "glutamine_10000.sum" file
# Properties extracted from "glycine_00000.sum" file
# Properties extracted from "glycine_01000.sum" file
# Properties extracted from "glycine_02000.sum" file
# Properties extracted from "glycine_03000.sum" file
# Properties extracted from "glycine_04000.sum" file
# Properties extracted from "glycine_05000.sum" file
# Properties extracted from "glycine_06000.sum" file
# Properties extracted from "glycine_07000.sum" file
# Properties extracted from "glycine_08000.sum" file
# Properties extracted from "glycine_09000.sum" file
# Properties extracted from "glycine_10000.sum" file
# Properties extracted from "histidine_00000.sum" file
# Properties extracted from "histidine_01000.sum" file
# Properties extracted from "histidine_02000.sum" file
# Properties extracted from "histidine_03000.sum" file
# Properties extracted from "histidine_04000.sum" file
# Properties extracted from "histidine_05000.sum" file
# Properties extracted from "histidine_06000.sum" file
# Properties extracted from "histidine_07000.sum" file
# Properties extracted from "histidine_08000.sum" file
# Properties extracted from "histidine_09000.sum" file
# Properties extracted from "histidine_10000.sum" file
# Properties extracted from "isoleucine_00000.sum" file
# Properties extracted from "isoleucine_01000.sum" file
# Properties extracted from "isoleucine_02000.sum" file
# Properties extracted from "isoleucine_03000.sum" file
# Properties extracted from "isoleucine_04000.sum" file
# Properties extracted from "isoleucine_05000.sum" file
# Properties extracted from "isoleucine_06000.sum" file
# Properties extracted from "isoleucine_07000.sum" file
# Properties extracted from "isoleucine_08000.sum" file
# Properties extracted from "isoleucine_09000.sum" file
# Properties extracted from "isoleucine_10000.sum" file
# Properties extracted from "leucine_00000.sum" file
# Properties extracted from "leucine_01000.sum" file
# Properties extracted from "leucine_02000.sum" file
# Properties extracted from "leucine_03000.sum" file
# Properties extracted from "leucine_04000.sum" file
# Properties extracted from "leucine_05000.sum" file
# Properties extracted from "leucine_06000.sum" file
# Properties extracted from "leucine_07000.sum" file
# Properties extracted from "leucine_08000.sum" file
# Properties extracted from "leucine_09000.sum" file
# Properties extracted from "leucine_10000.sum" file
# Properties extracted from "lysine_00000.sum" file
# Properties extracted from "lysine_01000.sum" file
# Properties extracted from "lysine_02000.sum" file
# Properties extracted from "lysine_03000.sum" file
# Properties extracted from "lysine_04000.sum" file
# Properties extracted from "lysine_05000.sum" file
# Properties extracted from "lysine_06000.sum" file
# Properties extracted from "lysine_07000.sum" file
# Properties extracted from "lysine_08000.sum" file
# Properties extracted from "lysine_09000.sum" file
# Properties extracted from "lysine_10000.sum" file
# Properties extracted from "methionine_00000.sum" file
# Properties extracted from "methionine_01000.sum" file
# Properties extracted from "methionine_02000.sum" file
# Properties extracted from "methionine_03000.sum" file
# Properties extracted from "methionine_04000.sum" file
# Properties extracted from "methionine_05000.sum" file
# Properties extracted from "methionine_06000.sum" file
# Properties extracted from "methionine_07000.sum" file
# Properties extracted from "methionine_08000.sum" file
# Properties extracted from "methionine_09000.sum" file
# Properties extracted from "methionine_10000.sum" file
# Properties extracted from "phenylalanine_00000.sum" file
# Properties extracted from "phenylalanine_01000.sum" file
# Properties extracted from "phenylalanine_02000.sum" file
# Properties extracted from "phenylalanine_03000.sum" file
# Properties extracted from "phenylalanine_04000.sum" file
# Properties extracted from "phenylalanine_05000.sum" file
# Properties extracted from "phenylalanine_06000.sum" file
# Properties extracted from "phenylalanine_07000.sum" file
# Properties extracted from "phenylalanine_08000.sum" file
# Properties extracted from "phenylalanine_09000.sum" file
# Properties extracted from "phenylalanine_10000.sum" file
# Properties extracted from "proline_00000.sum" file
# Properties extracted from "proline_01000.sum" file
# Properties extracted from "proline_02000.sum" file
# Properties extracted from "proline_03000.sum" file
# Properties extracted from "proline_04000.sum" file
# Properties extracted from "proline_05000.sum" file
# Properties extracted from "proline_06000.sum" file
# Properties extracted from "proline_07000.sum" file
# Properties extracted from "proline_08000.sum" file
# Properties extracted from "proline_09000.sum" file
# Properties extracted from "proline_10000.sum" file
# Properties extracted from "serine_00000.sum" file
# Properties extracted from "serine_01000.sum" file
# Properties extracted from "serine_02000.sum" file
# Properties extracted from "serine_03000.sum" file
# Properties extracted from "serine_04000.sum" file
# Properties extracted from "serine_05000.sum" file
# Properties extracted from "serine_06000.sum" file
# Properties extracted from "serine_07000.sum" file
# Properties extracted from "serine_08000.sum" file
# Properties extracted from "serine_09000.sum" file
# Properties extracted from "serine_10000.sum" file
# Properties extracted from "threonine_00000.sum" file
# Properties extracted from "threonine_01000.sum" file
# Properties extracted from "threonine_02000.sum" file
# Properties extracted from "threonine_03000.sum" file
# Properties extracted from "threonine_04000.sum" file
# Properties extracted from "threonine_05000.sum" file
# Properties extracted from "threonine_06000.sum" file
# Properties extracted from "threonine_07000.sum" file
# Properties extracted from "threonine_08000.sum" file
# Properties extracted from "threonine_09000.sum" file
# Properties extracted from "threonine_10000.sum" file
# Properties extracted from "tryptophan_00000.sum" file
# Properties extracted from "tryptophan_01000.sum" file
# Properties extracted from "tryptophan_02000.sum" file
# Properties extracted from "tryptophan_03000.sum" file
# Properties extracted from "tryptophan_04000.sum" file
# Properties extracted from "tryptophan_05000.sum" file
# Properties extracted from "tryptophan_06000.sum" file
# Properties extracted from "tryptophan_07000.sum" file
# Properties extracted from "tryptophan_08000.sum" file
# Properties extracted from "tryptophan_09000.sum" file
# Properties extracted from "tryptophan_10000.sum" file
# Properties extracted from "tyrosine_00000.sum" file
# Properties extracted from "tyrosine_01000.sum" file
# Properties extracted from "tyrosine_02000.sum" file
# Properties extracted from "tyrosine_03000.sum" file
# Properties extracted from "tyrosine_04000.sum" file
# Properties extracted from "tyrosine_05000.sum" file
# Properties extracted from "tyrosine_06000.sum" file
# Properties extracted from "tyrosine_07000.sum" file
# Properties extracted from "tyrosine_08000.sum" file
# Properties extracted from "tyrosine_09000.sum" file
# Properties extracted from "tyrosine_10000.sum" file
# Properties extracted from "valine_00000.sum" file
# Properties extracted from "valine_01000.sum" file
# Properties extracted from "valine_02000.sum" file
# Properties extracted from "valine_03000.sum" file
# Properties extracted from "valine_04000.sum" file
# Properties extracted from "valine_05000.sum" file
# Properties extracted from "valine_06000.sum" file
# Properties extracted from "valine_07000.sum" file
# Properties extracted from "valine_08000.sum" file
# Properties extracted from "valine_09000.sum" file
# Properties extracted from "valine_10000.sum" file
# All done !
