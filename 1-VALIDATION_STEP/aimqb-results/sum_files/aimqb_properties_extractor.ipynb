# %%
import os
import pandas as pd

all_files = os.listdir()
sum_files = [file for file in all_files if file.endswith(".sum")]
charge=[['Atom','Charge']] # atom_name + atom_charge
loc=[['Atom','Loc_index']] # atom_name + delocation_index
deloc=[['Atom(A)','Atom(B)','Deloc_index']] # atom_A + atom_B + delocation_index_AB
for output in sum_files:
    file = open(output)
    text = file.readlines()
    for line in range(len(text)):
         if text[line].startswith(('Atom A          q(A)              L(A)')): # ~charge
                i=1
                while True:
                    i+=1
                    if text[line+i].startswith('---'):
                        break
                    data_line = text[line+i].split()
                    charge.append([data_line[0],float(data_line[1])])
         
         if text[line].startswith(('Atom A          N(A)             LI(A)            %Loc(A)')): # ~loc
                i=1
                while True:
                    i+=1
                    if text[line+i].startswith('---'):
                        break
                    data_line = text[line+i].split()
                    loc.append([data_line[0],float(data_line[2])])
        
         if text[line].startswith(('Atom A    Atom B       2*D2(A,B)          DI(A,B)')): # ~deloc
                i=1
                while True:
                    i+=1
                    if text[line+i].startswith(' '):
                        break
                    data_line = text[line+i].split()
                    deloc.append([data_line[0],data_line[1],float(data_line[3])])
    df_charge = pd.DataFrame(charge)
    df_loc = pd.DataFrame(loc)
    df_deloc = pd.DataFrame(deloc)
    df_charge.to_csv(output[:-4]+'_charge.csv', sep=' ', index=False, header=False)
    df_loc.to_csv(output[:-4]+'_loc.csv', sep=' ', index=False, header=False)
    df_deloc.to_csv(output[:-4]+'_deloc.csv', sep=' ', index=False, header=False)
    charge = [charge[0]]
    loc = [loc[0]]
    deloc = [deloc[0]]
    print('Properties extracted from "'+output+'" file')
print('All done !')
# Out:
# Properties extracted from "alanine_b2plyp_6-311Gdp.sum" file
# Properties extracted from "alanine_b2plyp_6-31G.sum" file
# Properties extracted from "alanine_b2plyp_def2QZVP.sum" file
# Properties extracted from "alanine_b2plyp_def2SVP.sum" file
# Properties extracted from "alanine_b2plyp_def2TZVP.sum" file
# Properties extracted from "alanine_b3lyp_6-311Gdp.sum" file
# Properties extracted from "alanine_b3lyp_6-31G.sum" file
# Properties extracted from "alanine_b3lyp_def2QZVP.sum" file
# Properties extracted from "alanine_b3lyp_def2SVP.sum" file
# Properties extracted from "alanine_b3lyp_def2TZVP.sum" file
# Properties extracted from "alanine_m062X_6-311Gdp.sum" file
# Properties extracted from "alanine_m062X_6-31G.sum" file
# Properties extracted from "alanine_m062X_def2QZVP.sum" file
# Properties extracted from "alanine_m062X_def2SVP.sum" file
# Properties extracted from "alanine_m062X_def2TZVP.sum" file
# Properties extracted from "alanine_pbe0_6-311Gdp.sum" file
# Properties extracted from "alanine_pbe0_6-31G.sum" file
# Properties extracted from "alanine_pbe0_def2QZVP.sum" file
# Properties extracted from "alanine_pbe0_def2SVP.sum" file
# Properties extracted from "alanine_pbe0_def2TZVP.sum" file
# Properties extracted from "alanine_pbepbe_6-311Gdp.sum" file
# Properties extracted from "alanine_pbepbe_6-31G.sum" file
# Properties extracted from "alanine_pbepbe_def2QZVP.sum" file
# Properties extracted from "alanine_pbepbe_def2SVP.sum" file
# Properties extracted from "alanine_pbepbe_def2TZVP.sum" file
# Properties extracted from "arginine_b2plyp_6-311Gdp.sum" file
# Properties extracted from "arginine_b2plyp_6-31G.sum" file
# Properties extracted from "arginine_b2plyp_def2QZVP.sum" file
# Properties extracted from "arginine_b2plyp_def2SVP.sum" file
# Properties extracted from "arginine_b2plyp_def2TZVP.sum" file
# Properties extracted from "arginine_b3lyp_6-311Gdp.sum" file
# Properties extracted from "arginine_b3lyp_6-31G.sum" file
# Properties extracted from "arginine_b3lyp_def2QZVP.sum" file
# Properties extracted from "arginine_b3lyp_def2SVP.sum" file
# Properties extracted from "arginine_b3lyp_def2TZVP.sum" file
# Properties extracted from "arginine_m062X_6-311Gdp.sum" file
# Properties extracted from "arginine_m062X_6-31G.sum" file
# Properties extracted from "arginine_m062X_def2QZVP.sum" file
# Properties extracted from "arginine_m062X_def2SVP.sum" file
# Properties extracted from "arginine_m062X_def2TZVP.sum" file
# Properties extracted from "arginine_pbe0_6-311Gdp.sum" file
# Properties extracted from "arginine_pbe0_6-31G.sum" file
# Properties extracted from "arginine_pbe0_def2QZVP.sum" file
# Properties extracted from "arginine_pbe0_def2SVP.sum" file
# Properties extracted from "arginine_pbe0_def2TZVP.sum" file
# Properties extracted from "arginine_pbepbe_6-311Gdp.sum" file
# Properties extracted from "arginine_pbepbe_6-31G.sum" file
# Properties extracted from "arginine_pbepbe_def2QZVP.sum" file
# Properties extracted from "arginine_pbepbe_def2SVP.sum" file
# Properties extracted from "arginine_pbepbe_def2TZVP.sum" file
# Properties extracted from "aspargine_b2plyp_6-311Gdp.sum" file
# Properties extracted from "aspargine_b2plyp_6-31G.sum" file
# Properties extracted from "aspargine_b2plyp_def2QZVP.sum" file
# Properties extracted from "aspargine_b2plyp_def2SVP.sum" file
# Properties extracted from "aspargine_b2plyp_def2TZVP.sum" file
# Properties extracted from "aspargine_b3lyp_6-311Gdp.sum" file
# Properties extracted from "aspargine_b3lyp_6-31G.sum" file
# Properties extracted from "aspargine_b3lyp_def2QZVP.sum" file
# Properties extracted from "aspargine_b3lyp_def2SVP.sum" file
# Properties extracted from "aspargine_b3lyp_def2TZVP.sum" file
# Properties extracted from "aspargine_m062X_6-311Gdp.sum" file
# Properties extracted from "aspargine_m062X_6-31G.sum" file
# Properties extracted from "aspargine_m062X_def2QZVP.sum" file
# Properties extracted from "aspargine_m062X_def2SVP.sum" file
# Properties extracted from "aspargine_m062X_def2TZVP.sum" file
# Properties extracted from "aspargine_pbe0_6-311Gdp.sum" file
# Properties extracted from "aspargine_pbe0_6-31G.sum" file
# Properties extracted from "aspargine_pbe0_def2QZVP.sum" file
# Properties extracted from "aspargine_pbe0_def2SVP.sum" file
# Properties extracted from "aspargine_pbe0_def2TZVP.sum" file
# Properties extracted from "aspargine_pbepbe_6-311Gdp.sum" file
# Properties extracted from "aspargine_pbepbe_6-31G.sum" file
# Properties extracted from "aspargine_pbepbe_def2QZVP.sum" file
# Properties extracted from "aspargine_pbepbe_def2SVP.sum" file
# Properties extracted from "aspargine_pbepbe_def2TZVP.sum" file
# Properties extracted from "aspartic_b2plyp_6-311Gdp.sum" file
# Properties extracted from "aspartic_b2plyp_6-31G.sum" file
# Properties extracted from "aspartic_b2plyp_def2QZVP.sum" file
# Properties extracted from "aspartic_b2plyp_def2SVP.sum" file
# Properties extracted from "aspartic_b2plyp_def2TZVP.sum" file
# Properties extracted from "aspartic_b3lyp_6-311Gdp.sum" file
# Properties extracted from "aspartic_b3lyp_6-31G.sum" file
# Properties extracted from "aspartic_b3lyp_def2QZVP.sum" file
# Properties extracted from "aspartic_b3lyp_def2SVP.sum" file
# Properties extracted from "aspartic_b3lyp_def2TZVP.sum" file
# Properties extracted from "aspartic_m062X_6-311Gdp.sum" file
# Properties extracted from "aspartic_m062X_6-31G.sum" file
# Properties extracted from "aspartic_m062X_def2QZVP.sum" file
# Properties extracted from "aspartic_m062X_def2SVP.sum" file
# Properties extracted from "aspartic_m062X_def2TZVP.sum" file
# Properties extracted from "aspartic_pbe0_6-311Gdp.sum" file
# Properties extracted from "aspartic_pbe0_6-31G.sum" file
# Properties extracted from "aspartic_pbe0_def2QZVP.sum" file
# Properties extracted from "aspartic_pbe0_def2SVP.sum" file
# Properties extracted from "aspartic_pbe0_def2TZVP.sum" file
# Properties extracted from "aspartic_pbepbe_6-311Gdp.sum" file
# Properties extracted from "aspartic_pbepbe_6-31G.sum" file
# Properties extracted from "aspartic_pbepbe_def2QZVP.sum" file
# Properties extracted from "aspartic_pbepbe_def2SVP.sum" file
# Properties extracted from "aspartic_pbepbe_def2TZVP.sum" file
# Properties extracted from "cystine_b2plyp_6-311Gdp.sum" file
# Properties extracted from "cystine_b2plyp_6-31G.sum" file
# Properties extracted from "cystine_b2plyp_def2QZVP.sum" file
# Properties extracted from "cystine_b2plyp_def2SVP.sum" file
# Properties extracted from "cystine_b2plyp_def2TZVP.sum" file
# Properties extracted from "cystine_b3lyp_6-311Gdp.sum" file
# Properties extracted from "cystine_b3lyp_6-31G.sum" file
# Properties extracted from "cystine_b3lyp_def2QZVP.sum" file
# Properties extracted from "cystine_b3lyp_def2SVP.sum" file
# Properties extracted from "cystine_b3lyp_def2TZVP.sum" file
# Properties extracted from "cystine_m062X_6-311Gdp.sum" file
# Properties extracted from "cystine_m062X_6-31G.sum" file
# Properties extracted from "cystine_m062X_def2QZVP.sum" file
# Properties extracted from "cystine_m062X_def2SVP.sum" file
# Properties extracted from "cystine_m062X_def2TZVP.sum" file
# Properties extracted from "cystine_pbe0_6-311Gdp.sum" file
# Properties extracted from "cystine_pbe0_6-31G.sum" file
# Properties extracted from "cystine_pbe0_def2QZVP.sum" file
# Properties extracted from "cystine_pbe0_def2SVP.sum" file
# Properties extracted from "cystine_pbe0_def2TZVP.sum" file
# Properties extracted from "cystine_pbepbe_6-311Gdp.sum" file
# Properties extracted from "cystine_pbepbe_6-31G.sum" file
# Properties extracted from "cystine_pbepbe_def2QZVP.sum" file
# Properties extracted from "cystine_pbepbe_def2SVP.sum" file
# Properties extracted from "cystine_pbepbe_def2TZVP.sum" file
# Properties extracted from "glutamate_b2plyp_6-311Gdp.sum" file
# Properties extracted from "glutamate_b2plyp_6-31G.sum" file
# Properties extracted from "glutamate_b2plyp_def2QZVP.sum" file
# Properties extracted from "glutamate_b2plyp_def2SVP.sum" file
# Properties extracted from "glutamate_b2plyp_def2TZVP.sum" file
# Properties extracted from "glutamate_b3lyp_6-311Gdp.sum" file
# Properties extracted from "glutamate_b3lyp_6-31G.sum" file
# Properties extracted from "glutamate_b3lyp_def2QZVP.sum" file
# Properties extracted from "glutamate_b3lyp_def2SVP.sum" file
# Properties extracted from "glutamate_b3lyp_def2TZVP.sum" file
# Properties extracted from "glutamate_m062X_6-311Gdp.sum" file
# Properties extracted from "glutamate_m062X_6-31G.sum" file
# Properties extracted from "glutamate_m062X_def2QZVP.sum" file
# Properties extracted from "glutamate_m062X_def2SVP.sum" file
# Properties extracted from "glutamate_m062X_def2TZVP.sum" file
# Properties extracted from "glutamate_pbe0_6-311Gdp.sum" file
# Properties extracted from "glutamate_pbe0_6-31G.sum" file
# Properties extracted from "glutamate_pbe0_def2QZVP.sum" file
# Properties extracted from "glutamate_pbe0_def2SVP.sum" file
# Properties extracted from "glutamate_pbe0_def2TZVP.sum" file
# Properties extracted from "glutamate_pbepbe_6-311Gdp.sum" file
# Properties extracted from "glutamate_pbepbe_6-31G.sum" file
# Properties extracted from "glutamate_pbepbe_def2QZVP.sum" file
# Properties extracted from "glutamate_pbepbe_def2SVP.sum" file
# Properties extracted from "glutamate_pbepbe_def2TZVP.sum" file
# Properties extracted from "glutamine_b2plyp_6-311Gdp.sum" file
# Properties extracted from "glutamine_b2plyp_6-31G.sum" file
# Properties extracted from "glutamine_b2plyp_def2QZVP.sum" file
# Properties extracted from "glutamine_b2plyp_def2SVP.sum" file
# Properties extracted from "glutamine_b2plyp_def2TZVP.sum" file
# Properties extracted from "glutamine_b3lyp_6-311Gdp.sum" file
# Properties extracted from "glutamine_b3lyp_6-31G.sum" file
# Properties extracted from "glutamine_b3lyp_def2QZVP.sum" file
# Properties extracted from "glutamine_b3lyp_def2SVP.sum" file
# Properties extracted from "glutamine_b3lyp_def2TZVP.sum" file
# Properties extracted from "glutamine_m062X_6-311Gdp.sum" file
# Properties extracted from "glutamine_m062X_6-31G.sum" file
# Properties extracted from "glutamine_m062X_def2QZVP.sum" file
# Properties extracted from "glutamine_m062X_def2SVP.sum" file
# Properties extracted from "glutamine_m062X_def2TZVP.sum" file
# Properties extracted from "glutamine_pbe0_6-311Gdp.sum" file
# Properties extracted from "glutamine_pbe0_6-31G.sum" file
# Properties extracted from "glutamine_pbe0_def2QZVP.sum" file
# Properties extracted from "glutamine_pbe0_def2SVP.sum" file
# Properties extracted from "glutamine_pbe0_def2TZVP.sum" file
# Properties extracted from "glutamine_pbepbe_6-311Gdp.sum" file
# Properties extracted from "glutamine_pbepbe_6-31G.sum" file
# Properties extracted from "glutamine_pbepbe_def2QZVP.sum" file
# Properties extracted from "glutamine_pbepbe_def2SVP.sum" file
# Properties extracted from "glutamine_pbepbe_def2TZVP.sum" file
# Properties extracted from "glycine_b2plyp_6-311Gdp.sum" file
# Properties extracted from "glycine_b2plyp_6-31G.sum" file
# Properties extracted from "glycine_b2plyp_def2QZVP.sum" file
# Properties extracted from "glycine_b2plyp_def2SVP.sum" file
# Properties extracted from "glycine_b2plyp_def2TZVP.sum" file
# Properties extracted from "glycine_b3lyp_6-311Gdp.sum" file
# Properties extracted from "glycine_b3lyp_6-31G.sum" file
# Properties extracted from "glycine_b3lyp_def2QZVP.sum" file
# Properties extracted from "glycine_b3lyp_def2SVP.sum" file
# Properties extracted from "glycine_b3lyp_def2TZVP.sum" file
# Properties extracted from "glycine_m062X_6-311Gdp.sum" file
# Properties extracted from "glycine_m062X_6-31G.sum" file
# Properties extracted from "glycine_m062X_def2QZVP.sum" file
# Properties extracted from "glycine_m062X_def2SVP.sum" file
# Properties extracted from "glycine_m062X_def2TZVP.sum" file
# Properties extracted from "glycine_pbe0_6-311Gdp.sum" file
# Properties extracted from "glycine_pbe0_6-31G.sum" file
# Properties extracted from "glycine_pbe0_def2QZVP.sum" file
# Properties extracted from "glycine_pbe0_def2SVP.sum" file
# Properties extracted from "glycine_pbe0_def2TZVP.sum" file
# Properties extracted from "glycine_pbepbe_6-311Gdp.sum" file
# Properties extracted from "glycine_pbepbe_6-31G.sum" file
# Properties extracted from "glycine_pbepbe_def2QZVP.sum" file
# Properties extracted from "glycine_pbepbe_def2SVP.sum" file
# Properties extracted from "glycine_pbepbe_def2TZVP.sum" file
# Properties extracted from "histidine_b2plyp_6-311Gdp.sum" file
# Properties extracted from "histidine_b2plyp_6-31G.sum" file
# Properties extracted from "histidine_b2plyp_def2QZVP.sum" file
# Properties extracted from "histidine_b2plyp_def2SVP.sum" file
# Properties extracted from "histidine_b2plyp_def2TZVP.sum" file
# Properties extracted from "histidine_b3lyp_6-311Gdp.sum" file
# Properties extracted from "histidine_b3lyp_6-31G.sum" file
# Properties extracted from "histidine_b3lyp_def2QZVP.sum" file
# Properties extracted from "histidine_b3lyp_def2SVP.sum" file
# Properties extracted from "histidine_b3lyp_def2TZVP.sum" file
# Properties extracted from "histidine_m062X_6-311Gdp.sum" file
# Properties extracted from "histidine_m062X_6-31G.sum" file
# Properties extracted from "histidine_m062X_def2QZVP.sum" file
# Properties extracted from "histidine_m062X_def2SVP.sum" file
# Properties extracted from "histidine_m062X_def2TZVP.sum" file
# Properties extracted from "histidine_pbe0_6-311Gdp.sum" file
# Properties extracted from "histidine_pbe0_6-31G.sum" file
# Properties extracted from "histidine_pbe0_def2QZVP.sum" file
# Properties extracted from "histidine_pbe0_def2SVP.sum" file
# Properties extracted from "histidine_pbe0_def2TZVP.sum" file
# Properties extracted from "histidine_pbepbe_6-311Gdp.sum" file
# Properties extracted from "histidine_pbepbe_6-31G.sum" file
# Properties extracted from "histidine_pbepbe_def2QZVP.sum" file
# Properties extracted from "histidine_pbepbe_def2SVP.sum" file
# Properties extracted from "histidine_pbepbe_def2TZVP.sum" file
# Properties extracted from "isoleucine_b2plyp_6-311Gdp.sum" file
# Properties extracted from "isoleucine_b2plyp_6-31G.sum" file
# Properties extracted from "isoleucine_b2plyp_def2QZVP.sum" file
# Properties extracted from "isoleucine_b2plyp_def2SVP.sum" file
# Properties extracted from "isoleucine_b2plyp_def2TZVP.sum" file
# Properties extracted from "isoleucine_b3lyp_6-311Gdp.sum" file
# Properties extracted from "isoleucine_b3lyp_6-31G.sum" file
# Properties extracted from "isoleucine_b3lyp_def2QZVP.sum" file
# Properties extracted from "isoleucine_b3lyp_def2SVP.sum" file
# Properties extracted from "isoleucine_b3lyp_def2TZVP.sum" file
# Properties extracted from "isoleucine_m062X_6-311Gdp.sum" file
# Properties extracted from "isoleucine_m062X_6-31G.sum" file
# Properties extracted from "isoleucine_m062X_def2QZVP.sum" file
# Properties extracted from "isoleucine_m062X_def2SVP.sum" file
# Properties extracted from "isoleucine_m062X_def2TZVP.sum" file
# Properties extracted from "isoleucine_pbe0_6-311Gdp.sum" file
# Properties extracted from "isoleucine_pbe0_6-31G.sum" file
# Properties extracted from "isoleucine_pbe0_def2QZVP.sum" file
# Properties extracted from "isoleucine_pbe0_def2SVP.sum" file
# Properties extracted from "isoleucine_pbe0_def2TZVP.sum" file
# Properties extracted from "isoleucine_pbepbe_6-311Gdp.sum" file
# Properties extracted from "isoleucine_pbepbe_6-31G.sum" file
# Properties extracted from "isoleucine_pbepbe_def2QZVP.sum" file
# Properties extracted from "isoleucine_pbepbe_def2SVP.sum" file
# Properties extracted from "isoleucine_pbepbe_def2TZVP.sum" file
# Properties extracted from "leucine_b2plyp_6-311Gdp.sum" file
# Properties extracted from "leucine_b2plyp_6-31G.sum" file
# Properties extracted from "leucine_b2plyp_def2QZVP.sum" file
# Properties extracted from "leucine_b2plyp_def2SVP.sum" file
# Properties extracted from "leucine_b2plyp_def2TZVP.sum" file
# Properties extracted from "leucine_b3lyp_6-311Gdp.sum" file
# Properties extracted from "leucine_b3lyp_6-31G.sum" file
# Properties extracted from "leucine_b3lyp_def2QZVP.sum" file
# Properties extracted from "leucine_b3lyp_def2SVP.sum" file
# Properties extracted from "leucine_b3lyp_def2TZVP.sum" file
# Properties extracted from "leucine_m062X_6-311Gdp.sum" file
# Properties extracted from "leucine_m062X_6-31G.sum" file
# Properties extracted from "leucine_m062X_def2QZVP.sum" file
# Properties extracted from "leucine_m062X_def2SVP.sum" file
# Properties extracted from "leucine_m062X_def2TZVP.sum" file
# Properties extracted from "leucine_pbe0_6-311Gdp.sum" file
# Properties extracted from "leucine_pbe0_6-31G.sum" file
# Properties extracted from "leucine_pbe0_def2QZVP.sum" file
# Properties extracted from "leucine_pbe0_def2SVP.sum" file
# Properties extracted from "leucine_pbe0_def2TZVP.sum" file
# Properties extracted from "leucine_pbepbe_6-311Gdp.sum" file
# Properties extracted from "leucine_pbepbe_6-31G.sum" file
# Properties extracted from "leucine_pbepbe_def2QZVP.sum" file
# Properties extracted from "leucine_pbepbe_def2SVP.sum" file
# Properties extracted from "leucine_pbepbe_def2TZVP.sum" file
# Properties extracted from "lysine_b2plyp_6-311Gdp.sum" file
# Properties extracted from "lysine_b2plyp_6-31G.sum" file
# Properties extracted from "lysine_b2plyp_def2QZVP.sum" file
# Properties extracted from "lysine_b2plyp_def2SVP.sum" file
# Properties extracted from "lysine_b2plyp_def2TZVP.sum" file
# Properties extracted from "lysine_b3lyp_6-311Gdp.sum" file
# Properties extracted from "lysine_b3lyp_6-31G.sum" file
# Properties extracted from "lysine_b3lyp_def2QZVP.sum" file
# Properties extracted from "lysine_b3lyp_def2SVP.sum" file
# Properties extracted from "lysine_b3lyp_def2TZVP.sum" file
# Properties extracted from "lysine_m062X_6-311Gdp.sum" file
# Properties extracted from "lysine_m062X_6-31G.sum" file
# Properties extracted from "lysine_m062X_def2QZVP.sum" file
# Properties extracted from "lysine_m062X_def2SVP.sum" file
# Properties extracted from "lysine_m062X_def2TZVP.sum" file
# Properties extracted from "lysine_pbe0_6-311Gdp.sum" file
# Properties extracted from "lysine_pbe0_6-31G.sum" file
# Properties extracted from "lysine_pbe0_def2QZVP.sum" file
# Properties extracted from "lysine_pbe0_def2SVP.sum" file
# Properties extracted from "lysine_pbe0_def2TZVP.sum" file
# Properties extracted from "lysine_pbepbe_6-311Gdp.sum" file
# Properties extracted from "lysine_pbepbe_6-31G.sum" file
# Properties extracted from "lysine_pbepbe_def2QZVP.sum" file
# Properties extracted from "lysine_pbepbe_def2SVP.sum" file
# Properties extracted from "lysine_pbepbe_def2TZVP.sum" file
# Properties extracted from "methionine_b2plyp_6-311Gdp.sum" file
# Properties extracted from "methionine_b2plyp_6-31G.sum" file
# Properties extracted from "methionine_b2plyp_def2QZVP.sum" file
# Properties extracted from "methionine_b2plyp_def2SVP.sum" file
# Properties extracted from "methionine_b2plyp_def2TZVP.sum" file
# Properties extracted from "methionine_b3lyp_6-311Gdp.sum" file
# Properties extracted from "methionine_b3lyp_6-31G.sum" file
# Properties extracted from "methionine_b3lyp_def2QZVP.sum" file
# Properties extracted from "methionine_b3lyp_def2SVP.sum" file
# Properties extracted from "methionine_b3lyp_def2TZVP.sum" file
# Properties extracted from "methionine_m062X_6-311Gdp.sum" file
# Properties extracted from "methionine_m062X_6-31G.sum" file
# Properties extracted from "methionine_m062X_def2QZVP.sum" file
# Properties extracted from "methionine_m062X_def2SVP.sum" file
# Properties extracted from "methionine_m062X_def2TZVP.sum" file
# Properties extracted from "methionine_pbe0_6-311Gdp.sum" file
# Properties extracted from "methionine_pbe0_6-31G.sum" file
# Properties extracted from "methionine_pbe0_def2QZVP.sum" file
# Properties extracted from "methionine_pbe0_def2SVP.sum" file
# Properties extracted from "methionine_pbe0_def2TZVP.sum" file
# Properties extracted from "methionine_pbepbe_6-311Gdp.sum" file
# Properties extracted from "methionine_pbepbe_6-31G.sum" file
# Properties extracted from "methionine_pbepbe_def2QZVP.sum" file
# Properties extracted from "methionine_pbepbe_def2SVP.sum" file
# Properties extracted from "methionine_pbepbe_def2TZVP.sum" file
# Properties extracted from "phenylalanine_b2plyp_6-311Gdp.sum" file
# Properties extracted from "phenylalanine_b2plyp_6-31G.sum" file
# Properties extracted from "phenylalanine_b2plyp_def2QZVP.sum" file
# Properties extracted from "phenylalanine_b2plyp_def2SVP.sum" file
# Properties extracted from "phenylalanine_b2plyp_def2TZVP.sum" file
# Properties extracted from "phenylalanine_b3lyp_6-311Gdp.sum" file
# Properties extracted from "phenylalanine_b3lyp_6-31G.sum" file
# Properties extracted from "phenylalanine_b3lyp_def2QZVP.sum" file
# Properties extracted from "phenylalanine_b3lyp_def2SVP.sum" file
# Properties extracted from "phenylalanine_b3lyp_def2TZVP.sum" file
# Properties extracted from "phenylalanine_m062X_6-311Gdp.sum" file
# Properties extracted from "phenylalanine_m062X_6-31G.sum" file
# Properties extracted from "phenylalanine_m062X_def2QZVP.sum" file
# Properties extracted from "phenylalanine_m062X_def2SVP.sum" file
# Properties extracted from "phenylalanine_m062X_def2TZVP.sum" file
# Properties extracted from "phenylalanine_pbe0_6-311Gdp.sum" file
# Properties extracted from "phenylalanine_pbe0_6-31G.sum" file
# Properties extracted from "phenylalanine_pbe0_def2QZVP.sum" file
# Properties extracted from "phenylalanine_pbe0_def2SVP.sum" file
# Properties extracted from "phenylalanine_pbe0_def2TZVP.sum" file
# Properties extracted from "phenylalanine_pbepbe_6-311Gdp.sum" file
# Properties extracted from "phenylalanine_pbepbe_6-31G.sum" file
# Properties extracted from "phenylalanine_pbepbe_def2QZVP.sum" file
# Properties extracted from "phenylalanine_pbepbe_def2SVP.sum" file
# Properties extracted from "phenylalanine_pbepbe_def2TZVP.sum" file
# Properties extracted from "proline_b2plyp_6-311Gdp.sum" file
# Properties extracted from "proline_b2plyp_6-31G.sum" file
# Properties extracted from "proline_b2plyp_def2QZVP.sum" file
# Properties extracted from "proline_b2plyp_def2SVP.sum" file
# Properties extracted from "proline_b2plyp_def2TZVP.sum" file
# Properties extracted from "proline_b3lyp_6-311Gdp.sum" file
# Properties extracted from "proline_b3lyp_6-31G.sum" file
# Properties extracted from "proline_b3lyp_def2QZVP.sum" file
# Properties extracted from "proline_b3lyp_def2SVP.sum" file
# Properties extracted from "proline_b3lyp_def2TZVP.sum" file
# Properties extracted from "proline_m062X_6-311Gdp.sum" file
# Properties extracted from "proline_m062X_6-31G.sum" file
# Properties extracted from "proline_m062X_def2QZVP.sum" file
# Properties extracted from "proline_m062X_def2SVP.sum" file
# Properties extracted from "proline_m062X_def2TZVP.sum" file
# Properties extracted from "proline_pbe0_6-311Gdp.sum" file
# Properties extracted from "proline_pbe0_6-31G.sum" file
# Properties extracted from "proline_pbe0_def2QZVP.sum" file
# Properties extracted from "proline_pbe0_def2SVP.sum" file
# Properties extracted from "proline_pbe0_def2TZVP.sum" file
# Properties extracted from "proline_pbepbe_6-311Gdp.sum" file
# Properties extracted from "proline_pbepbe_6-31G.sum" file
# Properties extracted from "proline_pbepbe_def2QZVP.sum" file
# Properties extracted from "proline_pbepbe_def2SVP.sum" file
# Properties extracted from "proline_pbepbe_def2TZVP.sum" file
# Properties extracted from "serine_b2plyp_6-311Gdp.sum" file
# Properties extracted from "serine_b2plyp_6-31G.sum" file
# Properties extracted from "serine_b2plyp_def2QZVP.sum" file
# Properties extracted from "serine_b2plyp_def2SVP.sum" file
# Properties extracted from "serine_b2plyp_def2TZVP.sum" file
# Properties extracted from "serine_b3lyp_6-311Gdp.sum" file
# Properties extracted from "serine_b3lyp_6-31G.sum" file
# Properties extracted from "serine_b3lyp_def2QZVP.sum" file
# Properties extracted from "serine_b3lyp_def2SVP.sum" file
# Properties extracted from "serine_b3lyp_def2TZVP.sum" file
# Properties extracted from "serine_m062X_6-311Gdp.sum" file
# Properties extracted from "serine_m062X_6-31G.sum" file
# Properties extracted from "serine_m062X_def2QZVP.sum" file
# Properties extracted from "serine_m062X_def2SVP.sum" file
# Properties extracted from "serine_m062X_def2TZVP.sum" file
# Properties extracted from "serine_pbe0_6-311Gdp.sum" file
# Properties extracted from "serine_pbe0_6-31G.sum" file
# Properties extracted from "serine_pbe0_def2QZVP.sum" file
# Properties extracted from "serine_pbe0_def2SVP.sum" file
# Properties extracted from "serine_pbe0_def2TZVP.sum" file
# Properties extracted from "serine_pbepbe_6-311Gdp.sum" file
# Properties extracted from "serine_pbepbe_6-31G.sum" file
# Properties extracted from "serine_pbepbe_def2QZVP.sum" file
# Properties extracted from "serine_pbepbe_def2SVP.sum" file
# Properties extracted from "serine_pbepbe_def2TZVP.sum" file
# Properties extracted from "threonine_b2plyp_6-311Gdp.sum" file
# Properties extracted from "threonine_b2plyp_6-31G.sum" file
# Properties extracted from "threonine_b2plyp_def2QZVP.sum" file
# Properties extracted from "threonine_b2plyp_def2SVP.sum" file
# Properties extracted from "threonine_b2plyp_def2TZVP.sum" file
# Properties extracted from "threonine_b3lyp_6-311Gdp.sum" file
# Properties extracted from "threonine_b3lyp_6-31G.sum" file
# Properties extracted from "threonine_b3lyp_def2QZVP.sum" file
# Properties extracted from "threonine_b3lyp_def2SVP.sum" file
# Properties extracted from "threonine_b3lyp_def2TZVP.sum" file
# Properties extracted from "threonine_m062X_6-311Gdp.sum" file
# Properties extracted from "threonine_m062X_6-31G.sum" file
# Properties extracted from "threonine_m062X_def2QZVP.sum" file
# Properties extracted from "threonine_m062X_def2SVP.sum" file
# Properties extracted from "threonine_m062X_def2TZVP.sum" file
# Properties extracted from "threonine_pbe0_6-311Gdp.sum" file
# Properties extracted from "threonine_pbe0_6-31G.sum" file
# Properties extracted from "threonine_pbe0_def2QZVP.sum" file
# Properties extracted from "threonine_pbe0_def2SVP.sum" file
# Properties extracted from "threonine_pbe0_def2TZVP.sum" file
# Properties extracted from "threonine_pbepbe_6-311Gdp.sum" file
# Properties extracted from "threonine_pbepbe_6-31G.sum" file
# Properties extracted from "threonine_pbepbe_def2QZVP.sum" file
# Properties extracted from "threonine_pbepbe_def2SVP.sum" file
# Properties extracted from "threonine_pbepbe_def2TZVP.sum" file
# Properties extracted from "tryptophan_b2plyp_6-311Gdp.sum" file
# Properties extracted from "tryptophan_b2plyp_6-31G.sum" file
# Properties extracted from "tryptophan_b2plyp_def2QZVP.sum" file
# Properties extracted from "tryptophan_b2plyp_def2SVP.sum" file
# Properties extracted from "tryptophan_b2plyp_def2TZVP.sum" file
# Properties extracted from "tryptophan_b3lyp_6-311Gdp.sum" file
# Properties extracted from "tryptophan_b3lyp_6-31G.sum" file
# Properties extracted from "tryptophan_b3lyp_def2QZVP.sum" file
# Properties extracted from "tryptophan_b3lyp_def2SVP.sum" file
# Properties extracted from "tryptophan_b3lyp_def2TZVP.sum" file
# Properties extracted from "tryptophan_m062X_6-311Gdp.sum" file
# Properties extracted from "tryptophan_m062X_6-31G.sum" file
# Properties extracted from "tryptophan_m062X_def2QZVP.sum" file
# Properties extracted from "tryptophan_m062X_def2SVP.sum" file
# Properties extracted from "tryptophan_m062X_def2TZVP.sum" file
# Properties extracted from "tryptophan_pbe0_6-311Gdp.sum" file
# Properties extracted from "tryptophan_pbe0_6-31G.sum" file
# Properties extracted from "tryptophan_pbe0_def2QZVP.sum" file
# Properties extracted from "tryptophan_pbe0_def2SVP.sum" file
# Properties extracted from "tryptophan_pbe0_def2TZVP.sum" file
# Properties extracted from "tryptophan_pbepbe_6-311Gdp.sum" file
# Properties extracted from "tryptophan_pbepbe_6-31G.sum" file
# Properties extracted from "tryptophan_pbepbe_def2QZVP.sum" file
# Properties extracted from "tryptophan_pbepbe_def2SVP.sum" file
# Properties extracted from "tryptophan_pbepbe_def2TZVP.sum" file
# Properties extracted from "tyrosine_b2plyp_6-311Gdp.sum" file
# Properties extracted from "tyrosine_b2plyp_6-31G.sum" file
# Properties extracted from "tyrosine_b2plyp_def2QZVP.sum" file
# Properties extracted from "tyrosine_b2plyp_def2SVP.sum" file
# Properties extracted from "tyrosine_b2plyp_def2TZVP.sum" file
# Properties extracted from "tyrosine_b3lyp_6-311Gdp.sum" file
# Properties extracted from "tyrosine_b3lyp_6-31G.sum" file
# Properties extracted from "tyrosine_b3lyp_def2QZVP.sum" file
# Properties extracted from "tyrosine_b3lyp_def2SVP.sum" file
# Properties extracted from "tyrosine_b3lyp_def2TZVP.sum" file
# Properties extracted from "tyrosine_m062X_6-311Gdp.sum" file
# Properties extracted from "tyrosine_m062X_6-31G.sum" file
# Properties extracted from "tyrosine_m062X_def2QZVP.sum" file
# Properties extracted from "tyrosine_m062X_def2SVP.sum" file
# Properties extracted from "tyrosine_m062X_def2TZVP.sum" file
# Properties extracted from "tyrosine_pbe0_6-311Gdp.sum" file
# Properties extracted from "tyrosine_pbe0_6-31G.sum" file
# Properties extracted from "tyrosine_pbe0_def2QZVP.sum" file
# Properties extracted from "tyrosine_pbe0_def2SVP.sum" file
# Properties extracted from "tyrosine_pbe0_def2TZVP.sum" file
# Properties extracted from "tyrosine_pbepbe_6-311Gdp.sum" file
# Properties extracted from "tyrosine_pbepbe_6-31G.sum" file
# Properties extracted from "tyrosine_pbepbe_def2QZVP.sum" file
# Properties extracted from "tyrosine_pbepbe_def2SVP.sum" file
# Properties extracted from "tyrosine_pbepbe_def2TZVP.sum" file
# Properties extracted from "valine_b2plyp_6-311Gdp.sum" file
# Properties extracted from "valine_b2plyp_6-31G.sum" file
# Properties extracted from "valine_b2plyp_def2QZVP.sum" file
# Properties extracted from "valine_b2plyp_def2SVP.sum" file
# Properties extracted from "valine_b2plyp_def2TZVP.sum" file
# Properties extracted from "valine_b3lyp_6-311Gdp.sum" file
# Properties extracted from "valine_b3lyp_6-31G.sum" file
# Properties extracted from "valine_b3lyp_def2QZVP.sum" file
# Properties extracted from "valine_b3lyp_def2SVP.sum" file
# Properties extracted from "valine_b3lyp_def2TZVP.sum" file
# Properties extracted from "valine_m062X_6-311Gdp.sum" file
# Properties extracted from "valine_m062X_6-31G.sum" file
# Properties extracted from "valine_m062X_def2QZVP.sum" file
# Properties extracted from "valine_m062X_def2SVP.sum" file
# Properties extracted from "valine_m062X_def2TZVP.sum" file
# Properties extracted from "valine_pbe0_6-311Gdp.sum" file
# Properties extracted from "valine_pbe0_6-31G.sum" file
# Properties extracted from "valine_pbe0_def2QZVP.sum" file
# Properties extracted from "valine_pbe0_def2SVP.sum" file
# Properties extracted from "valine_pbe0_def2TZVP.sum" file
# Properties extracted from "valine_pbepbe_6-311Gdp.sum" file
# Properties extracted from "valine_pbepbe_6-31G.sum" file
# Properties extracted from "valine_pbepbe_def2QZVP.sum" file
# Properties extracted from "valine_pbepbe_def2SVP.sum" file
# Properties extracted from "valine_pbepbe_def2TZVP.sum" file
# All done !
